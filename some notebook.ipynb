# %% [markdown]
# # this is some notebook in some project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# create a time series df
np.random.seed(0)
dates = pd.date_range("20180101", periods=6)
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))
print(df)
# Out:
#                    A         B         C         D
# 2018-01-01  1.764052  0.400157  0.978738  2.240893
# 2018-01-02  1.867558 -0.977278  0.950088 -0.151357
# 2018-01-03 -0.103219  0.410599  0.144044  1.454274
# 2018-01-04  0.761038  0.121675  0.443863  0.333674
# 2018-01-05  1.494079 -0.205158  0.313068 -0.854096
# 2018-01-06 -2.552990  0.653619  0.864436 -0.742165

# %%
# plot it
df.plot()
# Out:
# <Axes: >
